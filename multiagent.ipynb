# %%
# !pip install -U langgraph langchain langchain-anthropic httpx
# Out:
# ...
#   Using cached langgraph-1.2.11-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached langgraph_checkpoint-4.2.0-py3-none-any.whl.metadata (6.7 kB)
# ...
#   Using cached langgraph_prebuilt-1.1.0-py3-none-any.whl.metadata (5.2 kB)
# ...
#   Using cached langgraph_sdk-0.4.4-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Using cached xxhash-4.0.1-cp314-cp314-win_amd64.whl.metadata (18 kB)
# ...
#   Using cached langchain_protocol-0.0.19-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached uuid_utils-0.17.1-cp314-cp314-win_amd64.whl.metadata (6.5 kB)
# ...
#   Using cached ormsgpack-1.12.2-cp314-cp314-win_amd64.whl.metadata (3.3 kB)
# ...
#   Using cached orjson-3.12.0-cp314-cp314-win_amd64.whl.metadata (43 kB)
# ...
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# ...
# Using cached langgraph-1.2.11-py3-none-any.whl (248 kB)
# ...
#    ---------------------------------------- 0.0/571.8 kB ? eta -:--:--
#    ------------------------------------ --- 524.3/571.8 kB 3.3 MB/s eta 0:00:01
# ...

# %%
# !pip install python-dotenv

# %%
import os
from dotenv import load_dotenv

load_dotenv()

api_key = os.getenv("GOOGLE_API_KEY")

print("API key loaded:", bool(api_key))
# Out:
# API key loaded: True
